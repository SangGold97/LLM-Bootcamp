# %% [markdown]
# ---
#
# # 📊 Summary of Exercises
#
# | Exercise | Name | Purpose | Difficulty |
# |-----|-----|----------|--------|
# | 1 | Basic Function Calling | Understand function calling logic | ⭐⭐ |
# | 2 | MCP Server | Create MCP server with tools | ⭐⭐⭐ |
# | 3 | MCP + LangChain | Integrate MCP into LangChain | ⭐⭐⭐ |
# | 4 | LangGraph Agent | Build agentic chatbot | ⭐⭐⭐⭐ |
# | Bonus | OpenAI Integration | Real connection with LLM API | ⭐⭐⭐⭐⭐ |
#
# ---
#
# # 🎯 Continue Learning
#
# After completing all exercises:
# 1. ✅ You understand **function calling** from A-Z
# 2. ✅ You know how to **create MCP Server**
# 3. ✅ You know how to **integrate MCP with LangChain**
# 4. ✅ You know how to **build agentic systems** with LangGraph
# 5. ✅ You can **deploy MCP server in practice**
#
# ---
#
# # 💡 Tips & Tricks
#
# ### Debugging
# - Use `print()` statements to track flow
# - Check input/output of each function
# - Verify schema formatting
#
# ### Testing
# - Write multiple test cases (normal, edge cases)
# - Test from basic → complex
# - Verify error handling
#
# ### Performance
# - MCP servers can run asynchronously
# - Implement caching if tools are slow
# - Monitor tool execution time
#
# ---
#
# # 📚 References
#
# - **MCP Official Docs**: https://modelcontextprotocol.io
# - **LangChain Docs**: https://python.langchain.com
# - **LangGraph Docs**: https://langchain-ai.github.io/langgraph
# - **OpenAI API Docs**: https://platform.openai.com/docs
#
# ---
#
# ## Good luck with your learning! 🚀

# %%
## BONUS 1: Connect with OpenAI API

# Install OpenAI
try:
    from openai import OpenAI
    print("✅ OpenAI library is installed")
except ImportError:
    print("⚠️  Installing OpenAI...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "openai"])
    from openai import OpenAI
    print("✅ Installation successful")

# TODO: Create Real Agent with OpenAI API
# INSTRUCTIONS:
# - Use OpenAI function calling API
# - Connect MCP Tools to OpenAI tools schema
# - Implement agent loop: LLM → tool call → result → continue
#
# STEPS:
# 1. Create OpenAI client
# 2. Format MCP tools into OpenAI function schema
# 3. Send user input + tools schema to OpenAI
# 4. Execute tool calls based on OpenAI response
# 5. Send results back to OpenAI
# 6. Loop until OpenAI stops

print("""
BONUS: Real OpenAI Integration

Requirements:
- OPENAI_API_KEY environment variable
- LangChain + OpenAI integration

Steps:
1. Initialize OpenAI client with API key
2. Create functions to convert MCP tools → OpenAI schema
3. Implement agent loop with actual LLM
4. Handle streaming (optional)

Example:
```python
from openai import OpenAI
client = OpenAI(api_key="sk-...")

# Format tools for OpenAI
tools_schema = [
    {
        "type": "function",
        "function": {
            "name": tool.name,
            "description": tool.description,
            "parameters": tool.args_schema
        }
    } for tool in langchain_tools
]

# Call OpenAI with tools
response = client.chat.completions.create(
    model="gpt-4",
    messages=[{"role": "user", "content": user_input}],
    tools=tools_schema
)

# Handle tool calls in response
# ...
```

Để implement: cần có valid OpenAI API key
""")

# %% [markdown]
# ---
#
# # BONUS: Kết Nối với OpenAI API (Optional)
#
# Nếu bạn muốn kết nối với OpenAI API in practice:

# %%
# TODO: Test Agentic Chatbot
# INSTRUCTIONS:
# - Create chatbot instance
# - Test with 2-3 complex user inputs
# - Verify multi-turn conversation (if needed)

print("=" * 60)
print("BÀI 4: Agentic Chatbot - TEST")
print("=" * 60)

test_inputs = [
    "What time is it?",
    "Reverse my name: Alice",
    "Count words in 'hello world test' and get current time",
]

# TODO: Implement tests
# chatbot = AgenticChatbot(langchain_tools)
# for test_input in test_inputs:
#     print(f"\n👤 User: {test_input}")
#     result = chatbot.run(test_input)
#     print(f"🤖 Assistant: {result}")

print("\n⚠️  Not completed - please test agentic chatbot")

# %%
# TODO: Tạo LangGraph Workflow
# HƯỚNG DẦN:
# - Tạo StateGraph với AgentState
# - Tạo 3 nodes:
#   * agent_node: LLM decides tools to call
#   * tool_node: Execute selected tools
#   * end_node: Generate final response
# - Define transitions/edges giữa nodes
# - Compile graph

# STRUCTURE:
# agent_node → (decide) → tool_node → (loop?) → agent_node
#                                             → end_node

class AgenticChatbot:
    """
    Agentic chatbot sử dụng LangGraph + MCP
    TODO: Implement
    """
    
    def __init__(self, tools: list):
        """
        Khởi create chatbot
        TODO: Tạo StateGraph, add nodes, add edges
        """
        self.tools = tools
        self.graph = None
    
    def _agent_node(self, state: AgentState) -> dict:
        """
        Agent Node: LLM nhận user input và tools schema
        Decide: Gọi tool nào?
        TODO: Implement
        """
        pass
    
    def _tool_node(self, state: AgentState) -> dict:
        """
        Tool Node: Thực thi tools được selected
        Update state với results
        TODO: Implement
        """
        pass
    
    def _end_node(self, state: AgentState) -> dict:
        """
        End Node: Generate final response
        TODO: Implement
        """
        pass
    
    def run(self, user_input: str) -> str:
        """
        Run chatbot
        TODO: Execute graph
        """
        pass

print("Chưa hoàn tact - hãy implement AgenticChatbot")

# %%
# Install LangGraph
try:
    from langgraph.graph import StateGraph
    print("✅ LangGraph is installed")
except ImportError:
    print("⚠️  Installing LangGraph...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "langgraph"])
    from langgraph.graph import StateGraph
    print("✅ Installation successful")

from typing import TypedDict, Annotated, Sequence
from datetime import datetime

# TODO: Define Agent State
# INSTRUCTIONS:
# - Create TypedDict AgentState with fields:
#   * messages: Sequence[str] - conversation history
#   * tools_called: Sequence[str] - tools called
#   * iteration_count: int - number of iterations
#   * final_response: str - final response

class AgentState(TypedDict):
    """
    State of agentic chatbot
    TODO: Define fields
    """
    pass

print("Not completed - please define AgentState")

# %% [markdown]
# ## 4.1 Exercise Description
#
# You will create a **complete Agentic Chatbot** using:
# - **LangGraph** to manage workflow
# - **MCP Tools** từ MCP Server
# - **Agent Loop** để thực thi multi-turn conversations
#
# ### Functionality:
# ```
# User: "What time is it and reverse my name 'John'"
# ↓
# Agent: Decides to call 2 tools: get_current_time, reverse_string
# ↓
# Tool Results: 2024-01-15 14:30:00, nhoJ
# ↓
# Agent: Generates final response combining both results
# ↓
# Response: "It's 2024-01-15 14:30:00. Your name reversed is 'nhoJ'"
# ```
#
# ## 4.2 LangGraph Agent Implementation

# %% [markdown]
# ---
#
# # EXERCISE 4: Agentic Chatbot with LangGraph + MCP

# %%
# TODO: Test MCP Client + LangChain Integration
# INSTRUCTIONS:
# - Test MCPClient.list_available_tools()
# - Test calling each tool through LangChain tools

print("=" * 60)
print("BÀI 3: MCP Client + LangChain - TEST")
print("=" * 60)

# TODO: Implement tests
# 1. Get tools from MCP Server
# 2. Check if there are exactly 4 tools
# 3. Call each tool and check results

print("\n⚠️  Not completed - please test integration")

# %%
# TODO: Create LangChain Tools from MCP Tools
# INSTRUCTIONS:
# - Get list of tools from MCP Client
# - For each tool, create StructuredTool
# - Store in list to use with LangChain Agent

# TODO: Implement
# mcp_client = MCPClient(utility_server)  # From Exercise 2
# 
# mcp_tools = mcp_client.list_available_tools()
# 
# langchain_tools = []
# for tool in mcp_tools:
#     # TODO: Create StructuredTool from MCP tool
#     #   - name: tool.name
#     #   - description: tool.description
#     #   - func: lambda or function calling mcp_client.call_tool()
#     #   - args_schema: tool.inputSchema
#     pass

print("Not completed - please create LangChain Tools")
print("""
STEPS:
1. Get tools from MCP Server
2. Create wrapper functions to call tools
3. Tạo StructuredTool objects
4. Store trong list
""")

# %%
# TODO: Create MCP Client
# INSTRUCTIONS:
# - Create MCPClient class to represent MCP Server connection
# - Implement methods:
#   * list_available_tools() - call @server.list_tools()
#   * call_tool(tool_name, **kwargs) - call @server.call_tool()

# Install LangChain
try:
    from langchain_core.tools import StructuredTool
    print("✅ LangChain is installed")
except ImportError:
    print("⚠️  Installing LangChain...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "langchain-core"])
    from langchain_core.tools import StructuredTool
    print("✅ Installation successful")

class MCPClient:
    """
    Client để kết nối với MCP Server
    TODO: Implement
    """
    
    def __init__(self, mcp_server):
        """
        Khởi create client với MCP server instance
        TODO: Store server reference
        """
        pass
    
    def list_available_tools(self):
        """
        Lấy danh sách tools từ server
        TODO: Gọi server.list_tools() (simulate)
        """
        pass
    
    async def call_tool(self, tool_name: str, **kwargs):
        """
        Gọi one tool từ server
        TODO: Gọi server.call_tool() với tool_name và kwargs
        """
        pass

print("Chưa hoàn tact - hãy implement MCPClient")

# %% [markdown]
# ## 3.1 Exercise Description
#
# You will:
# 1. Create **MCP Client** to connect with MCP Server from Exercise 2
# 2. Create **LangChain Tools** from MCP Server tools
# 3. Create **simple agent** using LangChain + MCP Tools
#
# ## 3.2 MCP Client Implementation

# %% [markdown]
# ---
#
# # EXERCISE 3: MCP Client + LangChain Integration

# %%
# TODO: Test MCP Server
# INSTRUCTIONS:
# - Simulate tool calls by calling @call_tool() handler directly
# - Or call server methods
# 
# Test cases:
# - Call get_current_time (no arguments needed)
# - Call format_text with text="hello world"
# - Call count_words with text="hello world test"
# - Call reverse_string with text="MCP"

print("=" * 60)
print("BÀI 2: MCP Server - TEST CASES")
print("=" * 60)

test_cases = [
    ("get_current_time", {}),
    ("format_text", {"text": "hello world"}),
    ("count_words", {"text": "hello world test"}),
    ("reverse_string", {"text": "MCP"}),
]

# TODO: Implement tests
# Gọi từng tool và in kết quả

print("\n⚠️  Chưa hoàn tact - hãy test các tools")

# %%
# TODO: Tạo MCP Server với 4 tools
# INSTRUCTIONS:
# - Tạo Server instance với name "utility-server"
# - Implement 4 tool handlers: get_current_time, format_text, count_words, reverse_string
# - Register tools sử dụng @server.list_tools()
# - Implement tool execution sử dụng @server.call_tool()
#
# REFERENCE từ THEORY:
# - server = Server("utility-server")
# - @server.call_tool() - decorator cho tool execution
# - @server.list_tools() - decorator cho tool discovery

from datetime import datetime
import json

# TODO: Tạo MCP Server
# utility_server = Server("utility-server")

# TODO: Implement @server.call_tool()
# Trong handler này, nhận tool_name và arguments
# Gọi function tương ứng và trả về kết quả
# 
# Ví dụ:
# if name == "get_current_time":
#     return [TextContent(type="text", text=str(datetime.now()))]

# TODO: Implement @server.list_tools()
# Trả về list các Tool objects với:
# - name, description, inputSchema

print("Chưa hoàn tact - hãy implement MCP Server")
print("""
STEPS:
1. Tạo Server instance
2. Implement @call_tool() handler
3. Implement @list_tools() handler
4. Define tool implementation functions
5. Test server (gọi tools)
""")

# %%
# Kiểm tra và cài đặt mcp library
try:
    from mcp.server import Server
    from mcp.types import Tool, TextContent, Resource
    print("✅ MCP library is installed")
except ImportError:
    print("⚠️  Cài đặt MCP library...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "mcp"])
    from mcp.server import Server
    from mcp.types import Tool, TextContent, Resource
    print("✅ Installation successful")

# %% [markdown]
# ## 2.1 Mô Tả Bài Tập
#
# Bạn sẽ create one **MCP Server hoàn chỉnh** với:
# - 4 tools: `get_current_time`, `format_text`, `count_words`, `reverse_string`
# - Resources: Một resource cho system info
# - Đúng format MCP (sử dụng `mcp` library)
#
# ## 2.2 MCP Server Implementation

# %% [markdown]
# ---
#
# # BÀI 2: Tạo MCP Server

# %%
# TODO 6: Test Function Calling
# INSTRUCTIONS:
# - Viết 3-5 test cases
# - Test các scenarios khác nhau (math, string length)
# - Verify outputs

print("=" * 60)
print("BÀI 1: Function Calling - TEST CASES")
print("=" * 60)

test_cases = [
    "What is 10 plus 5?",
    "How much is 100 minus 30?",
    "What is the length of 'hello'?",
]

# TODO: Implement tests
# for test_input in test_cases:
#     print()
#     result = function_calling_loop(test_input)
#     print(f"✅ Completed\n")

print("\n⚠️  Chưa hoàn tact - hãy run tests")

# %%
# TODO 5: Tạo Function Calling Loop
# INSTRUCTIONS:
# - Tạo function function_calling_loop(user_input)
# - Workflow:
#   1. LLM receives input và quyết định tool
#   2. Gọi tool từ registry
#   3. Format kết quả tact response cho user
# - In ra từng bước (để debug)

def function_calling_loop(user_input: str) -> str:
    """
    Thực thi function calling loop
    TODO: Implement
    """
    print(f"👤 User Input: {user_input}")
    print("-" * 60)
    
    # TODO: Implement 3 steps:
    # 1. Get LLM decision
    # 2. Call tool
    # 3. Format và return response
    
    # TEMPLATE:
    # llm_decision = mock_llm_decision(user_input)
    # if llm_decision is None:
    #     return "Tôi không hiểu request này"
    # 
    # tool_name, arguments = llm_decision
    # print(f"🤖 Gọi tool: {tool_name} với arguments: {arguments}")
    # 
    # result = registry.call_tool(tool_name, **arguments)
    # print(f"🔧 Result: {result}")
    # 
    # response = f"Tool {tool_name} trả về: {result}"
    # print(f"💬 Response: {response}")
    # 
    # return response
    
    pass

print("Chưa hoàn tact - hãy implement function_calling_loop")

# %%
# TODO 4: Tạo Mock LLM để quyết định gọi tool nào
# INSTRUCTIONS:
# - Tạo function mock_llm_decision(user_input) 
# - Dựa vào keywords trong user_input để quyết định tool
# - Trả về tuple (tool_name, arguments)
# 
# EXAMPLES:
# "What is 10 plus 5?" → ("add", {"a": 10, "b": 5})
# "20 minus 8?" → ("subtract", {"a": 20, "b": 8})
# "Length of hello" → ("get_length_of_string", {"s": "hello"})

def mock_llm_decision(user_input: str):
    """
    Mock LLM để phân tích user input và quyết định gọi tool nào
    TODO: Implement
    """
    user_lower = user_input.lower()
    
    # TODO: Implement heuristics/rules để phân tích input
    # - Nếu có từ "plus" or "add" → gọi add tool
    # - Nếu có từ "minus" or "subtract" → gọi subtract tool
    # - Nếu có từ "length" → gọi get_length_of_string tool
    # - Nếu không match → trả về None
    
    # HINTS: 
    # - Dùng user_lower để check keywords
    # - Extract numbers từ string (tìm cách để extract "10" và "5" từ "10 plus 5")
    # - Trả về (tool_name, {arguments})
    
    pass

print("Chưa hoàn tact - hãy implement mock_llm_decision")

# %%
# TODO 3: Đăng ký các tools vào Registry
# INSTRUCTIONS:
# - Tạo instance ToolRegistry
# - Gọi register() cho 3 tools (add, subtract, get_length_of_string)
# - Mỗi tool cần có description và parameters schema
#
# SCHEMA TEMPLATE:
# {
#     "type": "object",
#     "properties": {
#         "param_name": {"type": "string|number|integer", "description": "..."},
#         ...
#     },
#     "required": ["param1", "param2"]
# }

# TODO: Implement tool registration
registry = ToolRegistry()

# Register add tool
# registry.register(...)

# Register subtract tool
# registry.register(...)

# Register get_length_of_string tool
# registry.register(...)

print("Chưa hoàn tact - hãy đăng ký các tools")

# %%
# TODO 2: Tạo Tool Registry
# INSTRUCTIONS:
# - Tạo class ToolRegistry với methods:
#   * register(name, func, description, parameters)
#   * list_tools()
#   * call_tool(name, **kwargs)
# 
# ĐÂY LÀ FRAMEWORK, BẠNHÃY HỌC TỪ PHẦN 1 THEORY

from typing import Dict, Callable, Any

class ToolRegistry:
    """
    Registry để quản lý tất cả các tools
    TODO: Hoàn tact implementation
    """
    
    def __init__(self):
        # TODO: Khởi create one dictionary để store tools
        pass
    
    def register(self, name: str, func: Callable, description: str, parameters: Dict):
        """
        Register a tool
        TODO: Implement
        """
        pass
    
    def list_tools(self) -> list:
        """
        Trả về danh sách tất cả tools
        TODO: Implement - trả về list các tool objects
        """
        pass
    
    def call_tool(self, tool_name: str, **kwargs) -> Any:
        """
        Call a tool by name
        TODO: Implement - gọi function tương ứng với arguments
        """
        pass

print("Chưa hoàn tact - hãy implement ToolRegistry class")

# %%
# TODO 1: Định nghĩa các tools
# INSTRUCTIONS:
# - Tạo 3 functions: add(a, b), subtract(a, b), get_length_of_string(s)
# - Mỗi function cần có docstring
# 
# BẮT ĐẦU LẬP TRÌNH DỰA ĐÂY:

# Tools (hoàn tact code)
def add(a: float, b: float) -> float:
    """Cộng hai số"""
    # TODO: Implement
    pass

def subtract(a: float, b: float) -> float:
    """Trừ hai số (a - b)"""
    # TODO: Implement
    pass

def get_length_of_string(s: str) -> int:
    """Lấy độ long của string"""
    # TODO: Implement
    pass

# Test functions (run để verify implementation)
print("Chưa hoàn tact - hãy implement các functions trên")

# %% [markdown]
# ## 1.1 Mô Tả Bài Tập
#
# Bạn sẽ create one hệ thống function calling cơ version với:
# - 3 tools: `add`, `subtract`, `get_length_of_string`
# - 1 Registry để quản lý tools
# - 1 "Mock LLM" để quyết định gọi tool nào dựa trên user input
# - Function calling loop để thực thi
#
# ### Ví dụ Expected Output:
# ```
# Input: "What is 10 plus 5?"
# LLM Decision: Call tool "add" with a=10, b=5
# Tool Result: 15
# Final Response: "10 plus 5 equals 15"
# ```
#
# ## 1.2 Bắt Đầu Bài Tập

# %% [markdown]
# # MCP Exercises - Bài Tập Thực Hành
#
# ## 📌 Hướng Dẫn
#
# Trong notebook này, bạn sẽ hoàn tact các bài tập từ cơ version đến nâng cao:
#
# 1. **Bài 1**: Tạo Function Calling simple giản không use LLM API
# 2. **Bài 2**: Xây dựng MCP Server với các tools complex
# 3. **Bài 3**: Tích hợp MCP Server với mock LLM client
# 4. **Bài 4**: Tạo agentic chatbot với LangGraph + MCP
# 5. **Bonus**: Deploy MCP server và kết nối thực với OpenAI API
#
# ---
#
# ## ✅ Tiêu Chí Hoàn Tact
#
# Mỗi bài tập cần đảm bảo:
# - ✨ Code run được (không có syntax errors)
# - 📝 Có comments giải thích logic
# - 🧪 Có test cases để verify kết quả
# - 💡 Hiểu rõ từng bước (có thể giải thích cho người khác)
#
# ---
#
# # BÀI 1: Basic Function Calling (No LLM API)
